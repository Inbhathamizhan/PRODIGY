# %%
pip install pandas

# %%
#specifying delimiter
import pandas as pd
csv_file_path = '/content/API_SP.POP.2529.FE.5Y_DS2_en_csv_v2_2017938.csv'
df = pd.read_csv(csv_file_path, delimiter=';')  # Use the correct delimiter
print(df.head())
# Out:
#          Data Source,"World Development Indicators",
# 0                    Last Updated Date,"2024-06-28",
# 1  Country Name,"Country Code","Indicator Name","...
# 2  Aruba,"ABW","Population ages 25-29, female (% ...
# 3  Africa Eastern and Southern,"AFE","Population ...
# 4  Afghanistan,"AFG","Population ages 25-29, fema...

# %%
#skipping rows
import pandas as pd
csv_file_path = '/content/API_SP.POP.2529.FE.5Y_DS2_en_csv_v2_2017938.csv'
df = pd.read_csv(csv_file_path, skiprows=4)  # Adjust the number of rows to skip
print(df.head())
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                       Indicator Name     Indicator Code  \
# 0  Population ages 25-29, female (% of female pop...  SP.POP.2529.FE.5Y
# 1  Population ages 25-29, female (% of female pop...  SP.POP.2529.FE.5Y
# 2  Population ages 25-29, female (% of female pop...  SP.POP.2529.FE.5Y
# 3  Population ages 25-29, female (% of female pop...  SP.POP.2529.FE.5Y
# 4  Population ages 25-29, female (% of female pop...  SP.POP.2529.FE.5Y
#
#        1960      1961      1962      1963      1964      1965  ...      2015  \
# 0  7.469350  7.417326  7.330106  7.188939  7.052756  6.973942  ...  5.627650
# 1  7.420602  7.393628  7.363263  7.331737  7.300924  7.271023  ...  8.059290
# ...

# %%
pip install pandas numpy scikit-learn

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
# Path to your CSV file
csv_file_path = '/content/API_SP.POP.TOTL_DS2_en_csv_v2_2586629.csv'
# Load the CSV file into a DataFrame
df = pd.read_csv(csv_file_path, skiprows=4)
# Display the first few rows of the DataFrame
print("Initial DataFrame:")
print(df.head())
# Out:
# Initial DataFrame:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54608.0      55811.0      56682.0      57475.0      58178.0
# 1  130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2    8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3   97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4    5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
#
# ...

# %%
# Option 1: Remove rows with missing values
df_dropped = df.dropna()
print("\nDataFrame after dropping missing values:")
print(df_dropped.head())
# Out:
# DataFrame after dropping missing values:
# Empty DataFrame
# Columns: [Country Name, Country Code, Indicator Name, Indicator Code, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, Unnamed: 68]
# Index: []
#
# [0 rows x 69 columns]

# %%
#2. Encoding Categorical Variables
# Option 1: Label Encoding (for ordinal categories)
df['1960'] = df['1970'].astype('category').cat.codes

# %%
import matplotlib.pyplot as plt
# Load data from CSV file
df = pd.read_csv('/content/API_SP.POP.TOTL_DS2_en_csv_v2_2586629.csv', skiprows=4)
# Assuming CSV has columns 'Category' and 'Value'
categories = df['Country Code']
values = df['1960']
# Create bar chart
plt.figure(figsize=(10, 6))
plt.bar(categories, values, color='skyblue')
plt.xlabel('Category')
plt.ylabel('Value')
plt.title('Bar Chart from Population Data')
plt.xticks(rotation=45)
plt.tight_layout()
# Show plot
plt.show()

# %%
file_path = '/content/API_SP.POP.2529.FE.5Y_DS2_en_csv_v2_2017938.csv'  # Update this to the path of your CSV file
try:
    df = pd.read_csv(file_path, skiprows=4)  # Use skiprows if necessary to skip metadata rows
except pd.errors.ParserError as e:
    print(f"Error reading CSV file: {e}")
    exit()
print(df.head())
df_subset = df.head(25)
# Assuming the columns are 'Country Name' and 'Value' or adjust as needed
if 'Country Name' in df_subset.columns and '1960' in df_subset.columns:
    countries = df_subset['Country Name']
    values = df_subset['1960']
    # Create bar chart
    plt.figure(figsize=(12, 8))
    plt.bar(countries, values, color='pink')
    plt.xlabel('Country')
    plt.ylabel('Value')
    plt.title('Top 20 Countries by Value')
    plt.xticks(rotation=45)
    plt.tight_layout()
    # Show plot
    plt.show()
else:
    print("Expected columns 'Country Name' and 'Value' not found in the dataset.")
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                       Indicator Name     Indicator Code  \
# 0  Population ages 25-29, female (% of female pop...  SP.POP.2529.FE.5Y
# 1  Population ages 25-29, female (% of female pop...  SP.POP.2529.FE.5Y
# 2  Population ages 25-29, female (% of female pop...  SP.POP.2529.FE.5Y
# 3  Population ages 25-29, female (% of female pop...  SP.POP.2529.FE.5Y
# 4  Population ages 25-29, female (% of female pop...  SP.POP.2529.FE.5Y
#
#        1960      1961      1962      1963      1964      1965  ...      2015  \
# 0  7.469350  7.417326  7.330106  7.188939  7.052756  6.973942  ...  5.627650
# 1  7.420602  7.393628  7.363263  7.331737  7.300924  7.271023  ...  8.059290
# ...
